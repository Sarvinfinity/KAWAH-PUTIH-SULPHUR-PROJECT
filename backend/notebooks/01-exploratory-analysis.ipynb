# %% [markdown]
# # Kawah Putih Sulphur Hazard Intelligence System
#
# This notebook is a starter template for data exploration, feature engineering, and model experimentation.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
